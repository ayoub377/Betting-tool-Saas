# %%
# !pip install soccerdata
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import soccerdata as sd

# Create scraper class instance
fbref = sd.FBref()
# Out:
# [11/14/24 14:04:45] INFO     No custom team name replacements found. You can configure these in       ]8;id=804365;file://C:\Users\ayutt\transfermarkt-api\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=221363;file://C:\Users\ayutt\transfermarkt-api\.venv\Lib\site-packages\soccerdata\_config.py#90\90]8;;\
#                              C:\Users\ayutt\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=87008;file://C:\Users\ayutt\transfermarkt-api\.venv\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=421017;file://C:\Users\ayutt\transfermarkt-api\.venv\Lib\site-packages\soccerdata\_config.py#196\196]8;;\
#                              C:\Users\ayutt\soccerdata\config\league_dict.json.
# ...

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup']

# %%
import pandas as pd
data = pd.read_csv("brazil-stats.csv")

# %%
print(data.head())
# Out:
#    id  home_team_goals  dang_attacks  corners  away_team_gk_saves  clear_comp  \
# 0   1                2            38        9                   4          20
# 1   2                0            69        8                   0           5
# 2   3                2            70       13                   7           5
# 3   4                2            49        4                   4           3
# 4   5                2            53        6                   1           0
#
#    off_shot on_shot      team
# 0         4       6  Flamengo
# 1        11       0  Flamengo
# 2         4       9  Flamengo
# 3         9       6  Flamengo
# 4         7       3  Flamengo

# %%
print(data.tail())
# Out:
#     id  home_team_goals  dang_attacks  corners  away_team_gk_saves  \
# 25  10                3            80        9                  10
# 26  11                0            46        1                   2
# 27  12                1            14        3                   2
# 28  13                1            39        3                   4
# 29  14                0            45        7                   5
#
#     clear_comp  off_shot on_shot          team
# 25           1         9      13  Athletico Mg
# 26           2         1       2  Athletico Mg
# 27           3         2       3  Athletico Mg
# 28           5         9       5  Athletico Mg
# 29           4         5       5  Athletico Mg
